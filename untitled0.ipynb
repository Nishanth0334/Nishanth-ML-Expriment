# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanth0334/Nishanth-ML-Expriment/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# python program
# 1.addition of number,2.check a given numberis odd or even,3.checka number is prime or not,4.largest of four number,5.factorial of a number,6.reversing a number,7.check a given string is palidrom or no,8.sum of digit should add,9.create a multiplucation table,10.simple calculater

# %% [markdown]
# 1.addition of number,2.check a given number is odd or even,3.check a number is prime or not,4.largest of four number,5.factorial pf number,6.reversing a number,7.check a number is plainrom or not,8.sum of digit should add,9.create a multiplication table,10.simple calculater

# %%
1.
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sum = num1 + num2
print("The sum is:", sum)
# Out:
# Enter first number: 21
# Enter second number: 22
# The sum is: 43

# %%
2.
num = int(input("Enter a number: "))


if num % 2 == 0:
    print("The number is Even.")
else:
    print("The number is Odd.")
# Out:
# Enter a number: 5
# The number is Odd.

# %%
3.
num = int(input("Enter a number: "))


if num <= 1:
    print("The number is not a prime number.")
else:
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            print("The number is not a prime number.")
            break
    else:
        print("The number is a prime number.")
# Out:
# Enter a number: 5
# The number is a prime number.

# %%
4.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
d = int(input("Enter fourth number: "))
largest = max(a, b, c, d)
print("The largest number is:", largest)
# Out:
# Enter first number: 1
# Enter second number: 2
# Enter third number: 3
# Enter fourth number: 5
# The largest number is: 5

# %%
5.
import math

num = int(input("Enter a number: "))

if num < 0:
    print("Factorial does not exist for negative numbers.")
else:
    print("The factorial is:", math.factorial(num))
# Out:
# Enter a number: 5
# The factorial is: 120

# %%
6.
num = input("Enter a number: ")

# Reverse using slicing
reversed_num = num[::-1]

print("Reversed number is:", reversed_num)
# Out:
# Enter a number: 323
# Reversed number is: 323

# %%
7.
text = input("Enter a string: ")

if text == text[::-1]:
    print("It is a palindrome.")
else:
    print("It is not a palindrome.")
# Out:
# Enter a string: madam
# It is a palindrome.

# %%
8.
num = input("Enter a number: ")
total = 0

for digit in num:
    total += int(digit)

print("Sum of digits is:", total)
# Out:
# Enter a number: 56
# Sum of digits is: 11

# %%
9.
n = int(input("Enter a number: "))

print(f"Multiplication table for {n}:")

for i in range(1, 11):
    print(f"{n} x {i} = {n*i}")
# Out:
# Enter a number: 5
# Multiplication table for 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
10.
num1 = float(input("Enter first number: "))
op = input("Enter operation (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if op == '+':
    print("Result:", num1 + num2)
elif op == '-':
    print("Result:", num1 - num2)
elif op == '*':
    print("Result:", num1 * num2)
elif op == '/':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero.")
else:
    print("Invalid operation.")
# Out:
# Enter first number: 2
# Enter operation (+, -, *, /): +
# Enter second number: 3
# Result: 5.0

# %% [markdown]
# ## **New Section**
